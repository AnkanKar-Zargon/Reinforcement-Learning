# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import axes
import seaborn as sns

from environment import CartPoleEnv
from reinforce import REINFORCEAgent, BaselineREINFORCEAgent

# %%
# Initialize the GridWorld environment
env = CartPoleEnv()

# REINFORCE Algorithm
reinforce_agent = REINFORCEAgent(env)
reinforce_rewards = reinforce_agent.train(2000)


sns.set_style("darkgrid")
plt.figure(figsize=(30, 10),  facecolor= "#C1CDCD")
plt.plot(reinforce_rewards, label='REINFORCE Rewards', color = 'darkblue')
plt.xlabel('Episodes')
plt.ylabel('Total Reward')
plt.title('Learning Curve for REINFORCE Algorithm on Cart-Pole')
plt.grid(color = 'black')
plt.legend()
plt.show()

# Baseline REINFORCE Algorithm
baseline_reinforce_agent = BaselineREINFORCEAgent(env)
baseline_reinforce_rewards = baseline_reinforce_agent.train(2000)

sns.set_style("darkgrid")
plt.figure(figsize=(30, 10),  facecolor= "#C1CDCD")
plt.plot(baseline_reinforce_rewards, label='Baseline-REINFORCE Rewards', color = 'darkblue')
plt.xlabel('Episodes')
plt.ylabel('Total Reward')
plt.title('Learning Curve for Baseline-REINFORCE Algorithm on Cart-Pole')
plt.grid(color = 'black')
plt.legend()
plt.show()
